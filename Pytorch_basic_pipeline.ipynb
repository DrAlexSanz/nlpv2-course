# %% [markdown]
# <a href="https://colab.research.google.com/github/DrAlexSanz/nlpv2-course/blob/master/Pytorch_basic_pipeline.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Don't forget the .grad.zero_()!! It will be optimizer.zero_grad() --> optimizer.zero_grad()
#
# the _ at the end means inplace = True
#
# https://www.youtube.com/watch?v=c36lUUr864M

# %% [markdown]
# ![image.png](data:image/png;base64,...)
