# %% [markdown]
# <a href="https://colab.research.google.com/github/DrAlexSanz/nlpv2-course/blob/master/RNN_Theory.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# This is an RNN, each word will be a token (vector using embeddings), so there are several units inside X.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# And in a compact way

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# And when I include the sizes of the matrices, note that $W_x, W_h, W_o$ are different but they are the same through each time step

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# So at a given time step (0 to 1)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# And at step 1 to 2

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# And for a generic time step:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# And to see the shapes

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# How to use the RNN to solve a problem?

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# I could achieve the same using a CNN

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# And since this is deep learning, I can always stack layers on top of layers. It may help or it may not... But you still can do it.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# And all this applies to LSTMs or GRUs or whatever I invent. They are just spicy RNNs.
